# %% [markdown]
# ### Prepare environment

# %%
# %run ../environment/prepare_environment

# %% [markdown]
# ### Basic data exploration
#
# Basic data exploration can be performed using various methods:
# * build in DataFrame methods like `.summary()` or `.describe()`
# * using Databricks build-in profiler
# * using custom visualization libraries like `matplotlib` or `seaborn`

# %%
from pyspark.sql import functions as F

bronze_df = spark.sql("SELECT * FROM ai_ml_in_practice.telco_customer_churn_bronze.telco_bronze")

display(bronze_df)
display(bronze_df.describe())
