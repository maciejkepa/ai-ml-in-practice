# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS telco_customer_churn_raw")
spark.sql("CREATE SCHEMA IF NOT EXISTS telco_customer_churn_bronze")
spark.sql("CREATE VOLUME IF NOT EXISTS telco_customer_churn_raw.telco_data")

# %%
import shutil

local_path = "../environment/data/telco-customer-churn.csv"
volume_path = "/Volumes/ai_ml_in_practice/telco_customer_churn_raw/telco_data/telco-customer-churn.csv"

shutil.copy(
    local_path,
    volume_path
)

print("Environment ready.")
